# %%
import pandas as pd

# %%
df_1 = pd.read_csv('raw/dataset/veronika_all.csv', header=0, names=['ind', 'id', 'name', 'lat', 'lon', 'locality', 'region', 'neighbourhood'])
df_1 = df_1.drop(['ind'], axis=1)
df_1.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-eae78ebc2b7b> in <module>
# ----> 1 df_1 = pd.read_csv('raw/dataset/veronika_all.csv', header=0, names=['ind', 'id', 'name', 'lat', 'lon', 'locality', 'region', 'neighbourhood'])
#       2 df_1 = df_1.drop(['ind'], axis=1)
#       3 df_1.head()
#
# ...

# %%
df_2 = pd.read_csv('raw/dataset/ashish_1.csv', header=0, names=['id', 'lat', 'lon', 'name', 'locality', 'neighbourhood', 'region'])
df_2.head()
# Out:
#             id        lat        lon  \
# 0  49580341658  62.458197  25.933969
# 1  49580836626  62.458197  25.933969
# 2  49581064317  62.458002  25.934155
# 3  49580832151  62.458002  25.934155
# 4  49579613536  62.626369  27.122400
#
#                                          name    locality neighbourhood  \
# 0  Talwiajo Winter rally 2020_2020_02_08_0253      Laukaa         Kuusa
# 1  Talwiajo Winter rally 2020_2020_02_08_0251      Laukaa         Kuusa
# 2  Talwiajo Winter rally 2020_2020_02_08_0062      Laukaa         Kuusa
# 3  Talwiajo Winter rally 2020_2020_02_08_0060      Laukaa         Kuusa
# 4                                         NaN  Suonenjoki    Suonenjoki
#
#             region
# 0  Central Finland
# 1  Central Finland
# 2  Central Finland
# 3  Central Finland
# 4       North Savo

# %%
df_3 = pd.read_csv('raw/dataset/ashish_2.csv', header=0, names=['id', 'lat', 'lon', 'name', 'locality', 'neighbourhood', 'region'])
df_3.head()
# Out:
#             id        lat        lon                 name locality  \
# 0  50991878078  60.441099  26.851238          Deer on ice    Kotka
# 1  50989281247  60.665744  27.130058  2021-02-28_04-48-01   Hamina
# 2  50989169591  60.665744  27.130058  2021-02-28_04-47-16   Hamina
# 3  50989272377  60.662061  27.126758  2021-02-28_04-45-37   Hamina
# 4  50988447283  60.669961  27.171069  2021-02-28_04-42-07   Hamina
#
#   neighbourhood       region
# 0      Takakylä  Kymenlaakso
# 1     Metsäkylä  Kymenlaakso
# 2     Metsäkylä  Kymenlaakso
# 3     Metsäkylä  Kymenlaakso
# 4   Parkonpuoli  Kymenlaakso

# %%
df_4 = pd.read_csv('raw/dataset/ashish_3.csv', header=0, names=['id', 'lat', 'lon', 'name', 'locality', 'neighbourhood', 'region'])
df_4.head()
# Out:
#             id        lat        lon                       name   locality  \
# 0  50942928438  66.543536  25.847751                    041.365  Rovaniemi
# 1  50850068581  66.724228  26.741237  Arctic Lapland Rally 2021  Kemijärvi
# 2  50850161502  66.724160  26.741344  Arctic Lapland Rally 2021  Kemijärvi
# 3  50850063001  66.673054  26.548032  Arctic Lapland Rally 2021  Rovaniemi
# 4  50842727767  66.724220  26.741130  Arctic Lapland Rally 2021  Kemijärvi
#
#   neighbourhood   region
# 0     Nivavaara  Lapland
# 1       Sammale  Lapland
# 2       Sammale  Lapland
# 3         Nampa  Lapland
# 4       Sammale  Lapland

# %%
df = pd.concat([df_1, df_2, df_3, df_4])

# %%
duplicateRowsDF = df[df.duplicated()]
len(duplicateRowsDF)
# Out:
# 476

# %%
df = df.drop_duplicates()
len(df)
# Out:
# 77014

# %%
df.head()
# Out:
#             id                 name        lat        lon locality  \
# 0  50988380961  Late winter 2020-21  60.449969  22.265006    Turku
# 1  50988488177  Late winter 2020-21  60.449969  22.265006    Turku
# 2  50988380816  Late winter 2020-21  60.449969  22.265006    Turku
# 3  50988380741  Late winter 2020-21  60.449969  22.265006    Turku
# 4  50988487997  Late winter 2020-21  60.449969  22.265006    Turku
#
#            region neighbourhood
# 0  Finland Proper         Turku
# 1  Finland Proper         Turku
# 2  Finland Proper         Turku
# 3  Finland Proper         Turku
# 4  Finland Proper         Turku

# %%
df.to_csv('dataset/dataset.csv', index=False)
